# %%
# %pip install ultralytics
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
import torch
print(torch.version.cuda)       # kiểm tra phiên bản CUDA mà torch hiểu
print(torch.cuda.is_available()) # xem có detect GPU không
print(torch.cuda.device_count())
# Out:
# 12.1
# True
# 1

# %%
# !yolo task=detect mode=train model="yolo11n.pt" data="Detection/dataset.yaml" epochs=20 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.201  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...

# %%
from ultralytics import YOLO
import os

model = YOLO("yolo11n.pt")

# %%
# prompt: load mô hình /content/runs/detect/train4/weights/best.pt

model = YOLO('/content/runs/detect/train/weights/last.pt')

res = model.predict(source="/content/Detection/val/images/img_000013.jpg")
# Out:
# image 1/1 /content/Detection/val/images/img_000013.jpg: 640x640 3 dishs, 1 tray, 11.4ms
# Speed: 2.1ms preprocess, 11.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
res[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
# prompt: mở video: /content/drive/MyDrive/AU/Bản sao của 1473_CH05_20250501133703_154216.mp4
# phát hiện với video này

results = model.predict(source="/content/drive/MyDrive/AU/Bản sao của 1473_CH05_20250501133703_154216.mp4", save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/225395) /content/drive/MyDrive/AU/Bản sao của 1473_CH05_20250501133703_154216.mp4: 128x224 1 tray, 63.3ms
# video 1/1 (frame 2/225395) /content/drive/MyDrive/AU/Bản sao của 1473_CH05_20250501133703_154216.mp4: 128x224 1 tray, 8.1ms
# video 1/1 (frame 3/225395) /content/drive/MyDrive/AU/Bản sao của 1473_CH05_20250501133703_154216.mp4: 128x224 1 tray, 8.0ms
# ...
